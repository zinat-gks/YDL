# %% [markdown]
# # Road Accidents in Kazakhstan
#
# Source: [Kaggle — Road Accident in Kazakhstan](https://www.kaggle.com/datasets/ayazhanduisekhan/road-accident-in-kazakhstan)

# %%
import pandas as pd

FILE = "Dataset_pandas_assign.xlsx"

# %% [markdown]
# ## Read the file

# %%
# Read the Excel file (requires openpyxl). The workbook has a single sheet.
df = pd.read_excel(FILE)
df.head()
# Out:
#                       Unique number  Возраст, полных лет Гражданство  \
# 0                                 1                    2           3
# 1  74d88aec9cfe39a1bc5a93314c4326dc                   30   Казахстан
# 2  c13fe1fef2192e82056e26544c3efed3                   36   Казахстан
# 3  8dd751c0f9c0cf216303a0d445099e1b                   46   Казахстан
# 4  005f21aeed2db9c1694f724f365be6b5                   45   Казахстан
#
#    Стаж вождения Пол  КБМ       Город      Марка      Модель  \
# 0              4   5    6           7          8           9
# 1             10   М    8      Алматы        156  Alfa romeo
# 2             17   М    8  Нур-Султан        156  Alfa romeo
# 3             28   М    8      Алматы  Rsv 1000r     Aprilia
# 4             13   М    7  Нур-Султан         80        Audi
#
#                    Тип ТС           Год выпуска Расположение руля  \
# 0                       10                   11                12
# ...

# %% [markdown]
# ## Shape (rows, columns)

# %%
df.shape
# Out:
# (10910, 20)

# %% [markdown]
# ## Columns

# %%
df.columns
# Out:
# Index(['Unique number', 'Возраст, полных лет', 'Гражданство', 'Стаж вождения',
#        'Пол', 'КБМ', 'Город', 'Марка', 'Модель', 'Тип ТС ', 'Год выпуска',
#        'Расположение руля', 'Объём двигателя', 'Цвет', 'Период страхования',
#        'Страховая премия', 'Льготы', 'Дата проишествия', 'Регион ДТП',
#        'Сумма убытка'],
#       dtype='object')

# %% [markdown]
# ## Info (dtypes & non-null counts)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unique number        10910 non-null  object
#  1   Возраст, полных лет  10910 non-null  int64
#  2   Гражданство          10910 non-null  object
#  3   Стаж вождения        10910 non-null  int64
#  4   Пол                  10910 non-null  object
#  5   КБМ                  10910 non-null  int64
#  6   Город                10910 non-null  object
#  7   Марка                10910 non-null  object
#  8   Модель               10910 non-null  object
#  9   Тип ТС               10910 non-null  object
#  10  Год выпуска          10910 non-null  object
#  11  Расположение руля    10910 non-null  object
#  12  Объём двигателя      10910 non-null  int64
#  13  Цвет                 10910 non-null  object
#  14  Период страхования   10910 non-null  object
# ...
